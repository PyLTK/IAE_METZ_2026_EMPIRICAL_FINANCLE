# %%
# premier exercice

print("Machine learning")
# Out:
# Machine learning

# %% [markdown]
# # let's go learning python
# ## Donc on défini des variables

# %%
name="Nathon"
print(name)

# Pour les chiffres

Age=26 #integer donc nombre entier 
print(Age,name)

pi=3.14589 #float
pi
# Out:
# Nathon
# 26 Nathon
# 3.14589

# %%
#couple Clévaleur 
#un dictionnaire est une clé valeur 
prices= {
    "APPL": 248,
    "GOOGL": 328,
    "TSLA": 437
}

# %% [markdown]
# # comment avoir les données boursières

# %%
# !pip install yfinance
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 78.6 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 81.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 71.3 MB/s  0:00:00
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15637 sha256=5f898ec569f1e60a52d87b87afefe75f908c9f2abeb24e6a4272912792f44606
#   Stored in directory: /home/codespace/.cache/pip/wheels/cc/bd/6f/664d62c99327abeef7d86489e6631cbf45b56fbf7ef1d6ef00
# Successfully built multitasking
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [yfinance]/10 [yfinance]]]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 61.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 79.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 60.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 87.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
#  La structure d'un projet python :
#  une cellule ou on importe tous les packages
#  overview des dépendances

# %%
import yfinance as yf

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
ticker="AAPL"
data=yf.download(ticker, start="2020-01-01",end="2025-01-01", progress=False,auto_adjust=False)
print(data)
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2020-01-02   72.468262   75.087502   75.150002   73.797501   74.059998
# 2020-01-03   71.763710   74.357498   75.144997   74.125000   74.287498
# 2020-01-06   72.335556   74.949997   74.989998   73.187500   73.447502
# 2020-01-07   71.995354   74.597504   75.224998   74.370003   74.959999
# 2020-01-08   73.153473   75.797501   76.110001   74.290001   74.290001
# ...                ...         ...         ...         ...         ...
# 2024-12-24  257.037476  258.200012  258.209991  255.289993  255.490005
# 2024-12-26  257.853760  259.019989  260.100006  257.630005  258.190002
# 2024-12-27  254.439240  255.589996  258.700012  253.059998  257.829987
# 2024-12-30  251.064499  252.199997  253.500000  250.750000  252.229996
# 2024-12-31  249.292496  250.419998  253.279999  249.429993  252.440002
#
# Price          Volume
# ...

# %%
#pour prendre les données du package YF on utilise une fonction qui est def dans ce package pour extraire

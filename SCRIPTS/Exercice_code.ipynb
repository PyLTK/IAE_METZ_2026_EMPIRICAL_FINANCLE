# %%
# premier exercice

print("Machine learning")
# Out:
# Machine learning

# %% [markdown]
# # let's go learning python
# ## Donc on défini des variables

# %%
name="Nathon"
print(name)

# Pour les chiffres

Age=26 #integer donc nombre entier 
print(Age,name)

pi=3.14589 #float
pi
# Out:
# Nathon
# 26 Nathon
# 3.14589

# %%
#couple Clévaleur 
#un dictionnaire est une clé valeur 
prices= {
    "APPL": 248,
    "GOOGL": 328,
    "TSLA": 437
}
